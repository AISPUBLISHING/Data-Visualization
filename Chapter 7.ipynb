# %% [markdown]
# # Chapter 7: Pandas for Data Visualization

# %% [markdown]
# ### 7.1. Introduction

# %%
##$ pip install pandas

# %% [markdown]
# ### 7.2. Loading Datasets with Pandas

# %%
import pandas as pd
titanic_data = pd.read_csv(r"E:\Data Visualization with Python\Datasets\titanic_data.csv")
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 7.3. Plotting Histograms with Pandas

# %%
import matplotlib.pyplot as plt
titanic_data['Age'].hist()

# %%
import matplotlib.pyplot as plt
titanic_data['Age'].plot(kind='hist')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
titanic_data['Age'].hist(bins = 20)

# %%
titanic_data['Age'].hist(bins = 20, color = 'orange')

# %% [markdown]
# ### 7.4. Pandas Lineplots

# %%
flights_data = sns.load_dataset('flights')

flights_data.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights_data.plot.line( y='passengers', figsize=(8,6))

# %%
flights_data.plot.line( y='passengers', figsize=(8,6), color = 'orange')

# %%
flights_data.plot.line(x ='year', y='passengers', figsize=(8,6), color = 'orange')

# %% [markdown]
# ### 7.5. Pandas Scatter Plots

# %%
flights_data.plot.scatter(x='year', y='passengers', figsize=(8,6))

# %%
flights_data.plot.scatter(x='year', y='passengers', color='red', figsize=(8,6))

# %% [markdown]
# ### 7.6. Pandas Bar Plot

# %%
titanic_data = pd.read_csv(r"E:\Data Visualization with Python\Datasets\titanic_data.csv")
titanic_data.head()
sex_mean = titanic_data.groupby("Sex")["Age"].mean()

print(sex_mean)
print(type(sex_mean.tolist()))
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64
# <class 'list'>

# %%
df = pd.DataFrame({'Gender':['Female', 'Male'], 'Age':sex_mean.tolist()})
ax = df.plot.bar(x='Gender', y='Age', figsize=(8,6))

# %%
df = pd.DataFrame({'Gender':['Female', 'Male'], 'Age':sex_mean.tolist()})
ax = df.plot.barh(x='Gender', y='Age', figsize=(8,6))

# %%
df = pd.DataFrame({'Gender':['Female', 'Male'], 'Age':sex_mean.tolist()})
ax = df.plot.barh(x='Gender', y='Age', figsize=(8,6), color = 'orange')

# %% [markdown]
# ### 7.7. Pandas Box Plots

# %%
titanic_data = pd.read_csv(r"E:\Data Visualization with Python\Datasets\titanic_data.csv")
titanic_data.plot.box(figsize=(10,8))

# %% [markdown]
# ### 7.8. Pandas Hexagonal Plots

# %%
tips_data = sns.load_dataset('tips')

tips_data.plot.hexbin(x='total_bill', y='tip', gridsize=20, figsize=(8,6))

# %%
tips_data.plot.hexbin(x='total_bill', y='tip', gridsize=20, figsize=(8,6), color = 'blue')

# %% [markdown]
# ### 7.9. Pandas Kernel Density Plots

# %%
tips_data.plot.kde( y='tip',  figsize=(8,6), color = 'blue')

# %%
tips_data.plot.kde( y='total_bill',  figsize=(8,6), color = 'red')

# %% [markdown]
# ### 7.10. Time Series Data Visualization with Pandas

# %%
google_stock = pd.read_csv(r"E:\Data Visualization with Python\Datasets\google_data.csv")
google_stock.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-01-06  513.589966  514.761719  499.678131  500.585632  500.585632
# 1  2015-01-07  505.611847  505.855164  498.281952  499.727997  499.727997
# 2  2015-01-08  496.626526  502.101471  489.655640  501.303680  501.303680
# 3  2015-01-09  503.377991  503.537537  493.435272  494.811493  494.811493
# 4  2015-01-12  493.584869  494.618011  486.225067  491.201416  491.201416
#
#     Volume
# 0  2899900
# 1  2065000
# 2  3353500
# 3  2071300
# 4  2326700

# %%
google_stock['Date'] = google_stock['Date'].apply(pd.to_datetime)
google_stock.set_index('Date', inplace=True)
google_stock.plot.line( y='Open', figsize=(12,8))

# %% [markdown]
# #### 7.10.1. Time Sampling

# %%
google_stock.resample(rule='A').mean()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-12-31   602.676217   608.091468   596.722047   602.678382   602.678382
# 2016-12-31   743.732459   749.421629   737.597905   743.486707   743.486707
# 2017-12-31   921.121193   926.898963   915.331412   921.780837   921.780837
# 2018-12-31  1113.554101  1125.777606  1101.001658  1113.225134  1113.225134
# 2019-12-31  1187.009821  1196.787599  1178.523734  1188.393057  1188.393057
# 2020-12-31  1346.470011  1379.046672  1345.697998  1374.079997  1374.079997
#
#                   Volume
# Date
# 2015-12-31  2.071960e+06
# 2016-12-31  1.832266e+06
# 2017-12-31  1.476514e+06
# 2018-12-31  1.741965e+06
# 2019-12-31  1.414085e+06
# 2020-12-31  1.441767e+06

# %%
google_stock.resample(rule='M').mean()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-01-31   510.388728   515.352041   503.988300   510.248006   510.248006
# 2015-02-28   534.448454   540.111910   530.943141   536.519088   536.519088
# 2015-03-31   558.825290   562.627577   554.057018   558.183871   558.183871
# 2015-04-30   539.966811   543.839108   535.114912   539.304467   539.304467
# 2015-05-31   535.470502   539.167248   530.856650   535.238998   535.238998
# ...                 ...          ...          ...          ...          ...
# 2019-09-30  1217.599005  1228.892249  1209.628491  1220.839520  1220.839520
# 2019-10-31  1230.809995  1242.260774  1223.923043  1232.711744  1232.711744
# 2019-11-30  1302.348492  1311.498956  1296.424707  1304.278992  1304.278992
# 2019-12-31  1340.861415  1348.178531  1334.039190  1340.867635  1340.867635
# 2020-01-31  1346.470011  1379.046672  1345.697998  1374.079997  1374.079997
#
#                   Volume
# Date
# 2015-01-31  2.595550e+06
# 2015-02-28  1.715495e+06
# 2015-03-31  1.756709e+06
# 2015-04-30  2.017938e+06
# 2015-05-31  1.593295e+06
# ...                  ...
# 2019-09-30  1.344970e+06
# 2019-10-31  1.250361e+06
# 2019-11-30  1.246170e+06
# 2019-12-31  1.302719e+06
# 2020-01-31  1.441767e+06
#
# [61 rows x 6 columns]

# %%
google_stock['Open'].resample('A').mean()
# Out:
# Date
# 2015-12-31     602.676217
# 2016-12-31     743.732459
# 2017-12-31     921.121193
# 2018-12-31    1113.554101
# 2019-12-31    1187.009821
# 2020-12-31    1346.470011
# Freq: A-DEC, Name: Open, dtype: float64

# %%
google_stock['Open'].resample('A').mean().plot(kind='bar', figsize=(8,6))

# %%
google_stock['Open'].resample('A').mean().plot(kind='line', figsize=(8,6))

# %% [markdown]
# #### 7.10.2. Time Shifting

# %%
google_stock.shift(3).head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-01-06         NaN         NaN         NaN         NaN         NaN
# 2015-01-07         NaN         NaN         NaN         NaN         NaN
# 2015-01-08         NaN         NaN         NaN         NaN         NaN
# 2015-01-09  513.589966  514.761719  499.678131  500.585632  500.585632
# 2015-01-12  505.611847  505.855164  498.281952  499.727997  499.727997
#
#                Volume
# Date
# 2015-01-06        NaN
# 2015-01-07        NaN
# 2015-01-08        NaN
# 2015-01-09  2899900.0
# 2015-01-12  2065000.0

# %%
google_stock.shift(-3).tail()
# Out:
#                    Open    High          Low        Close    Adj Close  \
# Date
# 2019-12-30  1347.859985  1372.5  1345.543945  1360.660034  1360.660034
# 2019-12-31  1350.000000  1396.5  1350.000000  1394.209961  1394.209961
# 2020-01-02          NaN     NaN          NaN          NaN          NaN
# 2020-01-03          NaN     NaN          NaN          NaN          NaN
# 2020-01-06          NaN     NaN          NaN          NaN          NaN
#
#                Volume
# Date
# 2019-12-30  1186400.0
# 2019-12-31  1732300.0
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN

# %% [markdown]
# ## Excersise 7.1

# %% [markdown]
# ### Question 1

# %% [markdown]
# Which attribute to change color of Pandas graph:
#
# A- set_color() \
# B- define_color() \
# C- color() \
# D- None of the above
#
# Answer: C

# %% [markdown]
# ### Question 2

# %% [markdown]
# Which Pandas function is used to plot horizontal bar plot:
#
# A- horz_bar() \
# B- barh() \
# C- bar_horizontal() \
# D- horizontal_bar()
#
# Answer: B

# %% [markdown]
# ### Question 3

# %% [markdown]
# How to time shift pandas dataframe 5 rows back?
#
# A - shift_back(5) \
# B - shift(5) \
# c - shift_behind(-5) \
# D - shift(-5)
#
# Answer: D

# %% [markdown]
# ## Exercise 7.2

# %% [markdown]
# Display a bar plot using Titanic dataset that displays average age of the passengers who survived those who did not survive.

# %%
titanic_data = pd.read_csv(r"E:\Data Visualization with Python\Datasets\titanic_data.csv")
titanic_data.head()
surv_mean = titanic_data.groupby("Survived")["Age"].mean()

df = pd.DataFrame({'Survived':['No', 'Yes'], 'Age':surv_mean.tolist()})
ax = df.plot.bar(x='Survived', y='Age', figsize=(8,6))
